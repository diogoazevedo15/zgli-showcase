# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
from multiprocessing import Pool
import random
import re

# %% [markdown]
# #### 1. Tree Structure

# %%
class InnerNode:
    def __init__(self, name):
        self.name = name
        self.connectionOne = None
        self.connectionTwo = None
        self.connectionThree = None
        self.tempConnections = []
        self.hasInnerConnection = False
        
    def add_inner_node(self,node):
        self.tempConnections.append(node)
        self.hasInnerConnection = True
        
    def add_leaf(self,leaf):
        self.tempConnections.append(leaf)
        
    def is_not_full(self):
        return len(self.tempConnections) < 3
    
class LeafNode:
    def __init__(self, name):
        self.name = name
        self.innerConnection = None
        
    def add_node(self,node):
        self.innerConnection = node

# %% [markdown]
# #### 2. Generate Random Tree

# %%
def generate_random_tree(leaf_labels):
    
    """
        Generates a random tree from leaf_labels.

        Parameters
        ----------
        df : array_like
            A list with the labels of the objects to be put in a trenary tree structure.

        Returns
        -------
        tree_dict : dict
            A dictionary containing all the inner tree nodes and its connections to other inner nodes/ leafs.

        Notes
        --------
        Function returns error if leafs are less than 6.
    """
    
    if len(leaf_labels) < 6:
        raise Exception("There must be at least six objects to cluster.")
    
    inner_node_labels = np.array([])
    tree_dict = {}

    # Initialize inner nodes
    for n in range(0,len(leaf_labels)-2):
        inner_node_labels = np.append(inner_node_labels, ('n' + str(n)))

    # Tree dict
    for n in inner_node_labels:
        tree_dict[n] = np.array([])

    # print(f'leaf_lables: {leaf_labels}')
    # print(f'inner_node_labels: {inner_node_labels}')
    # print(f'tree_dict: {tree_dict}')

    # Create inner_node connections
    nodes_to_use = inner_node_labels.copy()
    for index,node in enumerate(inner_node_labels):

        if len(nodes_to_use) == 0:
            break

        if node in nodes_to_use:
            index = np.argwhere(nodes_to_use == node)
            nodes_to_use = np.delete(nodes_to_use, index)

        # Initialize root node
        if index == 0:

            # Roll for number of inner_node connections
            possible_rolls = np.arange(1,4)
            number_of_connections = np.random.choice(possible_rolls)

            # Create number of connections rolled
            for connection in range(number_of_connections):
                node_to_connect = nodes_to_use[0]
                nodes_to_use = np.delete(nodes_to_use, 0)
                tree_dict[node] = np.append(tree_dict[node], node_to_connect)
                tree_dict[node_to_connect] = np.append(tree_dict[node_to_connect], node)

        elif index != 0 and len(tree_dict[node]) < 3:

            # Roll for number of inner_node connection
            possible_rolls = np.arange(1,4-len(tree_dict[node]))
            number_of_connections = np.random.choice(possible_rolls)

            if number_of_connections > len(nodes_to_use):
                number_of_connections = len(nodes_to_use)

            # Create number of connections rolled
            for connection in range(number_of_connections):
                node_to_connect = nodes_to_use[0]
                nodes_to_use = np.delete(nodes_to_use, 0)
                tree_dict[node] = np.append(tree_dict[node], node_to_connect)
                tree_dict[node_to_connect] = np.append(tree_dict[node_to_connect], node)

    # Add leafs to inner_nodes
    for node in tree_dict.keys():

        number_of_leafs = range(3 - len(tree_dict[node]))

        for n in number_of_leafs:
            leaf = np.random.choice(leaf_labels,1)
            leaf_index = np.where(leaf_labels == leaf)
            leaf_labels = np.delete(leaf_labels,leaf_index)
            tree_dict[node] = np.append(tree_dict[node], leaf)
            
        
            
    return tree_dict

# %%
tree_dict = generate_random_tree(['a','b','c','d','e','f','g','h'])
tree_dict
# Out:
# {'n0': array(['n1', 'h', 'c'], dtype='<U32'),
#  'n1': array(['n0', 'n2', 'n3'], dtype='<U32'),
#  'n2': array(['n1', 'n4', 'f'], dtype='<U32'),
#  'n3': array(['n1', 'n5', 'e'], dtype='<U32'),
#  'n4': array(['n2', 'a', 'd'], dtype='<U32'),
#  'n5': array(['n3', 'b', 'g'], dtype='<U32')}

# %%
def select_two_unconected_nodes(tree_dict):
    
    """
        Selects two random (unconnected) inner nodes.

        Parameters
        ----------
        tree_dict : dict
            A dictionary containing all the inner tree nodes and its connections to other inner nodes/ leafs.

        Returns
        -------
        random_nodes : array_like
            A list with the names of two radom unconnected inner nodes.

    """
    
    # Select a random node
    nodes = list(tree_dict.keys())
    first_random_node = np.random.choice(nodes,1)
    
    # Remove random node and its connections from pool of nodes before choosing another
    nodes_to_remove = np.append([first_random_node[0]],tree_dict[first_random_node[0]])
    new_nodes = np.array([])
    
    # Create new node list containing only unconnected nodes
    for node in nodes:
        if node not in nodes_to_remove:
            new_nodes = np.append(new_nodes,node)
    
    # Select seccond random node
    second_random_node = np.random.choice(new_nodes,1)
    
    return [first_random_node, second_random_node]

# %%
def select_two_random_nodes_with_leafs(tree_dict):
    
    """
        Selects two random inner nodes.

        Parameters
        ----------
        tree_dict : dict
            A dictionary containing all the inner tree nodes and its connections to other inner nodes/ leafs.

        Returns
        -------
        random_nodes : array_like
            A list with the names of two random inner nodes.
        
    """
    # Get list of nodes
    nodes = np.array(list(tree_dict.keys()))
    
    # Regex for: starts with "n" and the next 1-5 characters are digits from 0-9
    pattern = "^[n][0-9]{1,5}$"
    
    # Initialize random nodes
    first_random_node = None
    second_random_node = None
    
    # Initialize leaf arrays
    leaf_indexes_1 = np.array([])
    leaf_indexes_2 = np.array([])
    
    # Search for first node with leafs
    while len(leaf_indexes_1) == 0:
        first_random_node = np.random.choice(nodes,1)
        for i,node in enumerate(tree_dict[first_random_node[0]]):
            if not re.match(pattern, node):
                leaf_indexes_1 = np.append(leaf_indexes_1,i)
                
    # Remove first random node from the options
    print(f'nodes:{nodes}')
    index = np.argwhere(nodes == first_random_node)
    nodes = np.delete(nodes, index)
    print(f'nodes:{nodes}')
    
    # Search for second node with leafs
    while len(leaf_indexes_2) == 0:
        second_random_node = np.random.choice(nodes,1)
        for i,node in enumerate(tree_dict[second_random_node[0]]):
            if not re.match(pattern, node):
                leaf_indexes_2 = np.append(leaf_indexes_2,i)
            
    
    return {first_random_node[0]: leaf_indexes_1, second_random_node[0]: leaf_indexes_2}

# %%
select_two_random_nodes_with_leafs(tree_dict)
# Out:
# nodes:['n0' 'n1' 'n2' 'n3' 'n4' 'n5']
# nodes:['n0' 'n1' 'n2' 'n4' 'n5']
# {'n3': array([2.]), 'n2': array([2.])}

# %%
def leaf_swap(tree_dict):
    
    # Select two random unconnected inner nodes
    random_nodes = select_two_random_nodes_with_leafs(tree_dict)
    
    # Select two random leafs to switch
    nodes = list(random_nodes.keys())
    print(f'nodes:{nodes}')
    random_leaf_1 = np.random.choice(random_nodes[nodes[0]])
    random_leaf_2 = np.random.choice(random_nodes[nodes[1]])
    
    # Save leaf values
    leaf_1_val = tree_dict[nodes[0]][int(random_leaf_1)]
    leaf_2_val = tree_dict[nodes[1]][int(random_leaf_2)]
    
    # Switch leaf values
    tree_dict[nodes[0]][int(random_leaf_1)] = leaf_2_val
    tree_dict[nodes[1]][int(random_leaf_2)] = leaf_1_val
    
    return tree_dict

leaf_swap(tree_dict)
# Out:
# nodes:['n0' 'n1' 'n2' 'n3' 'n4' 'n5']
# nodes:['n1' 'n2' 'n3' 'n4' 'n5']
# nodes:['n0', 'n3']
# {'n0': array(['n2', 'e', 'f'], dtype='<U32'),
#  'n1': array(['n3', 'n5', 'n4'], dtype='<U32'),
#  'n2': array(['n2', 'n0', 'a'], dtype='<U32'),
#  'n3': array(['n2', 'n1', 'g'], dtype='<U32'),
#  'n4': array(['n5', 'h', 'b'], dtype='<U32'),
#  'n5': array(['n4', 'c', 'd'], dtype='<U32')}

# %%
def swap_inner_nodes(tree_dict):
    
    # Select two random unconnected inner nodes
    random_nodes = select_two_unconected_nodes(tree_dict)
    print(random_nodes)
    
    for node in tree_dict.keys():

        
        new_connections = np.array([])
        for connection in tree_dict[node]:
            
            if connection == random_nodes[0]:
                new_connections = np.append(new_connections, random_nodes[1])
            elif connection == random_nodes[1]:
                new_connections = np.append(new_connections, random_nodes[0])
            else:
                new_connections = np.append(new_connections,connection)

        tree_dict[node] = new_connections
    
    # tree_dict[random]
    
    return tree_dict

swap_inner_nodes(tree_dict)
# Out:
# [array(['n0'], dtype='<U2'), array(['n4'], dtype='<U32')]
# {'n0': array(['n2', 'a', 'c'], dtype='<U32'),
#  'n1': array(['n3', 'n5', 'n4'], dtype='<U32'),
#  'n2': array(['n2', 'n0', 'f'], dtype='<U32'),
#  'n3': array(['n2', 'n1', 'e'], dtype='<U32'),
#  'n4': array(['n5', 'h', 'd'], dtype='<U32'),
#  'n5': array(['n4', 'b', 'g'], dtype='<U32')}

# %%
tree_dict = generate_random_tree(['a','b','c','d','e','f','g','h'])
tree_dict
# Out:
# {'n0': array(['n1', 'n2', 'f'], dtype='<U32'),
#  'n1': array(['n0', 'n3', 'h'], dtype='<U32'),
#  'n2': array(['n0', 'n4', 'n5'], dtype='<U32'),
#  'n3': array(['n1', 'g', 'b'], dtype='<U32'),
#  'n4': array(['n2', 'a', 'e'], dtype='<U32'),
#  'n5': array(['n2', 'd', 'c'], dtype='<U32')}

# %%
tree_dict['n0']
# Out:
# array([], dtype=float64)

# %%
leaf_labels = np.array(['a','b','c','d','e','f','g','h'])
inner_node_labels = np.array([])
tree_dict = {}

# Initialize inner nodes
for n in range(0,len(leaf_labels)-2):
    inner_node_labels = np.append(inner_node_labels, ('n' + str(n)))
    
# Tree dict
for n in inner_node_labels:
    tree_dict[n] = np.array([])
    
# print(f'leaf_lables: {leaf_labels}')
# print(f'inner_node_labels: {inner_node_labels}')
# print(f'tree_dict: {tree_dict}')

# Create inner_node connections
nodes_to_use = inner_node_labels.copy()
for index,node in enumerate(inner_node_labels):
    
    if len(nodes_to_use) == 0:
        break
    
    if node in nodes_to_use:
        index = np.argwhere(nodes_to_use == node)
        nodes_to_use = np.delete(nodes_to_use, index)
    
    # Initialize root node
    if index == 0:
        
        # Roll for number of inner_node connections
        possible_rolls = np.arange(1,4)
        number_of_connections = np.random.choice(possible_rolls)
        
        # Create number of connections rolled
        for connection in range(number_of_connections):
            node_to_connect = nodes_to_use[0]
            nodes_to_use = np.delete(nodes_to_use, 0)
            tree_dict[node] = np.append(tree_dict[node], node_to_connect)
            tree_dict[node_to_connect] = np.append(tree_dict[node_to_connect], node)
            
    elif index != 0 and len(tree_dict[node]) < 3:
        
        # Roll for number of inner_node connection
        possible_rolls = np.arange(1,4-len(tree_dict[node]))
        number_of_connections = np.random.choice(possible_rolls)
        
        if number_of_connections > len(nodes_to_use):
            number_of_connections = len(nodes_to_use)
        
        # Create number of connections rolled
        for connection in range(number_of_connections):
            node_to_connect = nodes_to_use[0]
            nodes_to_use = np.delete(nodes_to_use, 0)
            tree_dict[node] = np.append(tree_dict[node], node_to_connect)
            tree_dict[node_to_connect] = np.append(tree_dict[node_to_connect], node)
            
# Add leafs to inner_nodes
for node in tree_dict.keys():

    number_of_leafs = range(3 - len(tree_dict[node]))
    
    for n in number_of_leafs:
        leaf = np.random.choice(leaf_labels,1)
        leaf_index = np.where(leaf_labels == leaf)
        leaf_labels = np.delete(leaf_labels,leaf_index)
        tree_dict[node] = np.append(tree_dict[node], leaf)
# Out:
# leaf_lables: ['a' 'b' 'c' 'd' 'e' 'f' 'g' 'h']
# inner_node_labels: ['n0' 'n1' 'n2' 'n3' 'n4' 'n5']
# tree_dict: {'n0': array([], dtype=float64), 'n1': array([], dtype=float64), 'n2': array([], dtype=float64), 'n3': array([], dtype=float64), 'n4': array([], dtype=float64), 'n5': array([], dtype=float64)}

# %%
tree_dict
# Out:
# {'n0': array(['n1', 'n2', 'n3'], dtype='<U32'),
#  'n1': array(['n0', 'n4', 'n5'], dtype='<U32'),
#  'n2': array(['n0', 'g', 'd'], dtype='<U32'),
#  'n3': array(['n0', 'f', 'c'], dtype='<U32'),
#  'n4': array(['n1', 'a', 'b'], dtype='<U32'),
#  'n5': array(['n1', 'h', 'e'], dtype='<U32')}

# %%
leaf_labels = np.array(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
choice = np.random.choice(leaf_labels,1)
delete = np.where(leaf_lables == choice) 
print(f'chocie: {choice}')
print(f'delete: {delete}')

d = np.delete(leaf_labels,delete)

print(f'd:{d}')
# Out:
# chocie: ['g']
# delete: (array([6], dtype=int64),)
# d:['a' 'b' 'c' 'd' 'e' 'f' 'h']

# %%
np.arange(1,4-1)
# Out:
# array([1, 2])

# %%
for i in range(2):
    print(i)
# Out:
# 0
# 1

# %%
np.random.choice([1,2,3])
# Out:
# 2

# %%
leaf_lables = np.array(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'])
inner_node_labels = np.array(['n0', 'n1', 'n2', 'n3', 'n4', 'n5'])

node = inner_node_labels[0]
inner_node_labels = np.delete(inner_node_labels, 0)

print(node)
print(inner_node_labels)
# Out:
# n0
# ['n1' 'n2' 'n3' 'n4' 'n5']

# %%
leaf_labels = ['a','b','c','d','e','f','g','h']
inner_nodes = []
leaf_nodes = []

# Initialize leafs
for l in leaf_labels:
    leaf_nodes.append(LeafNode(l))

# Initialize inner nodes
for n in range(0,len(leaf_labels)-2):
    inner_nodes.append(InnerNode('n' + str(n)))
    
tree = []
leafs = []

count = 0
while inner_nodes:
    print(f'########################################')
    print(f'##### Count:{count} #####')
    print(f'inner_nodes:{len(inner_nodes)}')
    
    # Define node as first in Queue
    node = inner_nodes.pop(0)
    nodes_used_indexes = []
    
    print(f'node:{node.name}')
    
    # Add inner connection if node does not have any
    if not node.hasInnerConnection:

        # Choose random inner node (index, node)
        random_choice = random.choice(list(enumerate(inner_nodes)))
        random_node = inner_nodes[random_choice[0]]
        nodes_used_indexes.append(random_choice[0])

        # Connect node and random node
        node.add_inner_node(random_node.name)
        random_node.add_inner_node(node.name)
    
    while node.is_not_full():
        
        # Choose to add leaf or inner node
        leaf_or_node = random.choice([0,1])
        
        # Add node
        if len(inner_nodes) == 2:
            
            print('1 if')
            # Connect node and random node
            node.add_inner_node(inner_nodes[1].name)
            inner_nodes[1].add_inner_node(node.name)
        
        # Add leaf
        elif (leaf_or_node == 0 and len(leaf_nodes) > 0):
            
            print('2 if')
            
            # Choose leaf
            random_choice = random.choice(list(enumerate(leaf_nodes)))
            random_leaf = leaf_nodes.pop(random_choice[0])
            
            # Connect leaf to node
            node.add_leaf(random_leaf.name)
                    
        # Add node
        elif (leaf_or_node == 1 and len(inner_nodes) > 2):
            
            # Choose node
            select_unused_node = True
            random_choice = None
            random_node = None
            
            # Chose only unselected nodes
            while select_unused_node:
                print('3 if')
                random_choice = random.choice(list(enumerate(inner_nodes)))
                random_node = inner_nodes[random_choice[0]]
                
                if random_choice[0] not in nodes_used_indexes:
                    select_unused_node = False
                    nodes_used_indexes.append(random_choice[0])   
            
            # Connect node and random node
            node.add_inner_node(random_node.name)
            random_node.add_inner_node(node.name)
                   
    print(f'nodes_used:{nodes_used_indexes}')
    
    # Add full nodes to tree
    remove = []
    for i in nodes_used_indexes:
        if not inner_nodes[i].is_not_full():
            tree.append(inner_nodes[i])
            remove.append(i)
    
    # Delete full elements from inner nodes
    for i in remove:
        del inner_nodes[i]

    # Append current node      
    tree.append(node)
# Out:
# ########################################
# ##### Count:0 #####
# inner_nodes:6
# node:n0
# 3 if
# 3 if
# 3 if
# 3 if
# 3 if
# nodes_used:[4, 0, 1]
# ########################################
# ##### Count:0 #####
# inner_nodes:5
# node:n1
# 2 if
# 3 if
# nodes_used:[0]
# ########################################
# ##### Count:0 #####
# inner_nodes:4
# node:n2
# 2 if
# nodes_used:[]
# ########################################
# ##### Count:0 #####
# inner_nodes:3
# node:n3
# 1 if
# 1 if
# nodes_used:[1]
# ########################################
# ##### Count:0 #####
# inner_nodes:1
# node:n4
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11452\3003360551.py in <module>
#      30
#      31         # Choose random inner node (index, node)
# ---> 32         random_choice = random.choice(list(enumerate(inner_nodes)))
#      33         random_node = inner_nodes[random_choice[0]]
#      34         nodes_used_indexes.append(random_choice[0])
#
# ~\anaconda3\lib\random.py in choice(self, seq)
#     344         """Choose a random element from a non-empty sequence."""
#     345         # raises IndexError if seq is empty
# --> 346         return seq[self._randbelow(len(seq))]
#     347
#     348     def shuffle(self, x, random=None):
#
# IndexError: list index out of range

# %%
for node in tree:
    print(node.name,node.tempConnections)
# Out:
# n0 ['n5', 'n1', 'n2']
# n1 ['n0', 'c', 'n2']
# n2 ['n0', 'n1', 'b']
# n5 ['n0', 'n3', 'n3', 'n3']
# n3 ['n5', 'n5', 'n5']

# %%
leaf_labels = ['a','b','c','d','e','f','g','h']
inner_nodes = []
leaf_nodes = []
rng = np.random.default_rng()

# Initialize leafs
for l in leaf_labels:
    leaf_nodes.append(LeafNode(l))

# Initialize inner nodes
for n in range(0,len(leaf_labels)):
    inner_nodes.append(InnerNode('n' + str(n)))
    
tree = []
leafs = []

inner_nodes
# Out:
# [<__main__.InnerNode at 0x20775b67d60>,
#  <__main__.InnerNode at 0x20775b67820>,
#  <__main__.InnerNode at 0x20775b67dc0>,
#  <__main__.InnerNode at 0x20775c02f10>,
#  <__main__.InnerNode at 0x20775c02670>,
#  <__main__.InnerNode at 0x20775c026d0>,
#  <__main__.InnerNode at 0x20775c029d0>,
#  <__main__.InnerNode at 0x20775c02640>]

# %%
for i in range(1,4):
    print(i)
# Out:
# 1
# 2
# 3

# %%
for node in inner_nodes:
    inner_nodes.pop(node)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10968\4105933945.py in <module>
#       1 for node in inner_nodes:
# ----> 2     inner_nodes.pop(node)
#       3
#
# TypeError: 'InnerNode' object cannot be interpreted as an integer

# %%
inner_nodes[0].get_conections_status()
# Out:
# array([False, False, False])

# %%
a = np.array([InnerNode('test'),None,None])
a != InnerNode
# Out:
# array([ True,  True,  True])

# %%
a = ['a',2,3,4]
rng = np.random.default_rng()
rng.choice(a)
# Out:
# '4'

# %%
np.where(a == id(rng.choice(a)))
# Out:
# (array([], dtype=int64),)

# %%
leaf_labels = ['a','b','c','d','e','f','g','h']
inner_nodes = []
leaf_nodes = []
rng = np.random.default_rng()

# Initialize leafs
for l in leaf_labels:
    leaf_nodes.append(LeafNode(l))

# Initialize inner nodes
for n in range(0,len(leafs)):
    inner_nodes.append(InnerNode('n' + str(n)))

# %%
np.where( == id(rng.choice(inner_nodes)))
# Out:
# (array([], dtype=int64),)

# %%
rng.choice([0,1])
# Out:
# 1
