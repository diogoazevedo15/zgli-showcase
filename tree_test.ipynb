# %%
from tree import read_distance_matrix, make_tree, make_clusters, make_color_tree
from zgli.folder import Folder

# %%
# Define Parameters
data_path = '../0.data/activity_data_1'
compressor = 'bzlib'
output_path = '../1.dms/'

# Initialize Folder class
folder = Folder(data_path)

# Compute matrix
dm = folder.distance_matrix(compressor, output_path)
# Out:
# Compressing Files...
# 0it [00:00, ?it/s]
# Compressing Appended Files...
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]

# %%
# dm_path = '../datapark/datapark/1.Mds_Hy_prediction/0.data/ncd_matrices/decimal/trunk/bzlib/1/algorithm-bzlib_decimals-9_byCol-1.txt'
# ext = '.csv'

# dm_path = '1.example_dms/distmatrix_10.txt'
# ext = '.txt'

dm_path = '../0.data/activity_data_1'
ext = '.csv'

dm, leaf_labels = read_distance_matrix(dm_path , file_extension = ext)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20352\1150861036.py in <module>
#       8 ext = '.csv'
#       9
# ---> 10 dm, leaf_labels = read_distance_matrix(dm_path , file_extension = ext)
#
# ~\Projetos_Python\zgli_dev\tree.py in read_distance_matrix(dm_path, file_extension)
#     178     """
#     179
# --> 180     data = np.loadtxt(dm_path, delimiter = file_extension, dtype=str)
#     181     labels = data.T[0]
#     182     dm = data.T[1:].T
#
# ~\anaconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1065             fname = os_fspath(fname)
#    1066         if _is_string_like(fname):
# -> 1067             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
# ...

# %%
processes = 10
inner_node_dict, leaf_dict = make_tree(dm, leaf_labels, processes, n_trees = 300)

# %%
cluster_labels, cluster_label_dict = make_clusters(5, 'average', leaf_dict, inner_node_dict, dm, leaf_labels, 10, True)

# %%
make_color_tree(inner_node_dict, leaf_dict, cluster_label_dict)

# %%
len(leaf_labels)
