# %%
from tree import read_distance_matrix, make_tree, make_clusters, make_color_tree

# %%
dm_path = '../datapark/datapark/1.Mds_Hy_prediction/0.data/ncd_matrices/decimal/trunk/bzlib/1/algorithm-bzlib_decimals-9_byCol-1.txt'
ext = '.csv'

# dm_path = '1.example_dms/distmatrix_10.txt'
# ext = '.txt'

dm, leaf_labels = read_distance_matrix(dm_path , file_extension = ext)

# %%
processes = 10
inner_node_dict, leaf_dict = make_tree(dm, leaf_labels, processes, n_trees = 300)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9296\744053050.py in <module>
#       1 processes = 10
# ----> 2 inner_node_dict, leaf_dict = make_tree(dm, leaf_labels, processes, n_trees = 300)
#
# ~\Projetos_Python\zgli_dev\tree.py in make_tree(dm, leaf_labels, processes, n_trees)
#    1015     # all_quartets = generate_all_quartets(leaf_labels)
#    1016     leaf_pairs_with_paths = get_leaf_pairs_with_paths(leaf_pairs, get_graph(inner_node_dict, leaf_dict), processes)
# -> 1017     min_tree_cost, max_tree_cost = compute_min_max_tree_costs(leaf_labels,dm)
#    1018     tree_score = compute_tree_score(leaf_labels, leaf_pairs_with_paths, min_tree_cost, max_tree_cost, dm)
#    1019
#
# ~\Projetos_Python\zgli_dev\tree.py in compute_min_max_tree_costs(leaf_labels, dm)
#     786         costs = []
#     787         for possible_quartet in three_possible_quartets:
# --> 788             costs.append(compute_quartet_cost(dm,leaf_labels,possible_quartet))
#     789         min_tree_cost += min(costs)
#     790         max_tree_cost += max(costs)
#
# ~\Projetos_Python\zgli_dev\tree.py in compute_quartet_cost(dm, labels, quartet)
#     673
#     674     pair_one_i = [np.argwhere(labels == node)[0][0] for node in pair_one]
# --> 675     pair_two_i = [np.argwhere(labels == node)[0][0] for node in pair_two]
#     676
#     677     cost_one = dm[pair_one_i[0]][pair_one_i[1]]
#
# ~\Projetos_Python\zgli_dev\tree.py in <listcomp>(.0)
#     673
#     674     pair_one_i = [np.argwhere(labels == node)[0][0] for node in pair_one]
# --> 675     pair_two_i = [np.argwhere(labels == node)[0][0] for node in pair_two]
#     676
#     677     cost_one = dm[pair_one_i[0]][pair_one_i[1]]
#
# <__array_function__ internals> in argwhere(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\numeric.py in argwhere(a)
#     616         # then remove the added dimension
#     617         return argwhere(a)[:,:0]
# --> 618     return transpose(nonzero(a))
#     619
#     620
#
# <__array_function__ internals> in transpose(*args, **kwargs)
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in transpose(a, axes)
#     658
#     659     """
# --> 660     return _wrapfunc(a, 'transpose', axes)
#     661
#     662
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      52     bound = getattr(obj, method, None)
#      53     if bound is None:
# ---> 54         return _wrapit(obj, method, *args, **kwds)
#      55
#      56     try:
#
# ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py in _wrapit(obj, method, *args, **kwds)
#      41     except AttributeError:
#      42         wrap = None
# ---> 43     result = getattr(asarray(obj), method)(*args, **kwds)
#      44     if wrap:
#      45         if not isinstance(result, mu.ndarray):
#
# KeyboardInterrupt:

# %%
cluster_labels, cluster_label_dict = make_clusters(5, 'average', leaf_dict, inner_node_dict, dm, leaf_labels, 10, True)

# %%
make_color_tree(inner_node_dict, leaf_dict, cluster_label_dict)

# %%
len(leaf_labels)
# Out:
# 222
